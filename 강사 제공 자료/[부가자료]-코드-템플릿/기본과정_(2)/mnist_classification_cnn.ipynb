# %% [markdown]
# # Mnist Classification

# %% [markdown]
# ### mnist 데이터 학습을 위해 keras로 cnn 모델을 구성하여 학습을 진행해본다.

# %%
##tenssorflow==2.3 환경에서 구현 
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

(mnist_train, mnist_train_label), (mnist_test, mnist_test_label) = mnist.load_data() #mnist data road
#normalization 적용
mnist_train=mnist_train/255
mnist_test=mnist_test/255

mnist_train=tf.cast(mnist_train, tf.float32)
mnist_train=np.expand_dims(mnist_train, -1)
mnist_test=tf.cast(mnist_test, tf.float32)
mnist_test=np.expand_dims(mnist_test, -1)
#one hot encoding
train_labels = to_categorical(mnist_train_label, 10)
test_labels = to_categorical(mnist_test_label, 10) 

class_number = 10

# %%
# keras functional api로 짧은 mlp 모델을 구성 
inputs = tf.keras.Input(shape=(28,28,1))
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=16, activation='relu',padding="same")(inputs)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(1, 1))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(1, 1))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(2, 2))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(2, 2))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(2, 2))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Flatten()(x)
outputs = tf.keras.layers.Dense(class_number, activation="softmax")(x)
model = tf.keras.Model(inputs=inputs,outputs=outputs)
model.summary()
model.compile(optimizer='adam', # #보편적으로 가장 많이 사용하는 adam optimizer 활용,loss로 categorical cross entropy 지정
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(mnist_train, train_labels, epochs=100)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 27, 27, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 256)         295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# dense (Dense)                (None, 3, 3, 256)         65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                23050
# =================================================================
# Total params: 481,162
# Trainable params: 481,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1908 - accuracy: 0.9371
# Epoch 2/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0612 - accuracy: 0.9816
# Epoch 3/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0511 - accuracy: 0.9848
# Epoch 4/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0447 - accuracy: 0.9864
# Epoch 5/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0410 - accuracy: 0.9869
# Epoch 6/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0368 - accuracy: 0.9885
# Epoch 7/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0347 - accuracy: 0.9892
# Epoch 8/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0350 - accuracy: 0.9891
# Epoch 9/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0324 - accuracy: 0.9900
# Epoch 10/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0326 - accuracy: 0.9902
# Epoch 11/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0324 - accuracy: 0.9902
# Epoch 12/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0328 - accuracy: 0.9902
# Epoch 13/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0319 - accuracy: 0.9907
# Epoch 14/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0302 - accuracy: 0.9906
# Epoch 15/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0317 - accuracy: 0.9906
# Epoch 16/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0318 - accuracy: 0.9905
# Epoch 17/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0355 - accuracy: 0.9896
# Epoch 18/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0318 - accuracy: 0.9904
# Epoch 19/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0313 - accuracy: 0.9910
# Epoch 20/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0330 - accuracy: 0.9908
# Epoch 21/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0318 - accuracy: 0.9914
# Epoch 22/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0322 - accuracy: 0.9908
# Epoch 23/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0333 - accuracy: 0.9905
# Epoch 24/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0317 - accuracy: 0.9907
# Epoch 25/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0328 - accuracy: 0.9907
# Epoch 26/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0348 - accuracy: 0.9897
# Epoch 27/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0320 - accuracy: 0.9910
# Epoch 28/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0375 - accuracy: 0.9897
# Epoch 29/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0328 - accuracy: 0.9905
# Epoch 30/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0341 - accuracy: 0.9909
# Epoch 31/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0369 - accuracy: 0.9898
# Epoch 32/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0369 - accuracy: 0.9896
# Epoch 33/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0347 - accuracy: 0.9905
# Epoch 34/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0361 - accuracy: 0.9901
# Epoch 35/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0384 - accuracy: 0.9899
# Epoch 36/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0362 - accuracy: 0.9902
# Epoch 37/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0361 - accuracy: 0.9901
# Epoch 38/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0373 - accuracy: 0.9895
# Epoch 39/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0335 - accuracy: 0.9907
# Epoch 40/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0357 - accuracy: 0.9908
# Epoch 41/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0393 - accuracy: 0.9889
# Epoch 42/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0416 - accuracy: 0.9886
# Epoch 43/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0365 - accuracy: 0.9901
# Epoch 44/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0394 - accuracy: 0.9895
# Epoch 45/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0424 - accuracy: 0.9897
# Epoch 46/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0374 - accuracy: 0.9896
# Epoch 47/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0368 - accuracy: 0.9903
# Epoch 48/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0391 - accuracy: 0.9901
# Epoch 49/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0403 - accuracy: 0.9894
# Epoch 50/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0396 - accuracy: 0.9897
# Epoch 51/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0382 - accuracy: 0.9901
# Epoch 52/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0386 - accuracy: 0.9897
# Epoch 53/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0406 - accuracy: 0.9890
# Epoch 54/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0371 - accuracy: 0.9909
# Epoch 55/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0437 - accuracy: 0.9889
# Epoch 56/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0423 - accuracy: 0.9886
# Epoch 57/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0423 - accuracy: 0.9884
# Epoch 58/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0405 - accuracy: 0.9894
# Epoch 59/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0401 - accuracy: 0.9896
# Epoch 60/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0423 - accuracy: 0.9889
# Epoch 61/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0416 - accuracy: 0.9889
# Epoch 62/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0426 - accuracy: 0.9888
# Epoch 63/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0433 - accuracy: 0.9882
# Epoch 64/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0413 - accuracy: 0.9891
# Epoch 65/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0429 - accuracy: 0.9888
# Epoch 66/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0420 - accuracy: 0.9892
# Epoch 67/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0458 - accuracy: 0.9881
# Epoch 68/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0430 - accuracy: 0.9886
# Epoch 69/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0439 - accuracy: 0.9893
# Epoch 70/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0413 - accuracy: 0.9888
# Epoch 71/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0428 - accuracy: 0.9887
# Epoch 72/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0440 - accuracy: 0.9884
# Epoch 73/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0397 - accuracy: 0.9898
# Epoch 74/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0420 - accuracy: 0.9891
# Epoch 75/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0401 - accuracy: 0.9894
# Epoch 76/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0408 - accuracy: 0.9898
# Epoch 77/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0375 - accuracy: 0.9908
# Epoch 78/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0413 - accuracy: 0.9894
# Epoch 79/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0453 - accuracy: 0.9882
# Epoch 80/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0425 - accuracy: 0.9890
# Epoch 81/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0401 - accuracy: 0.9897
# Epoch 82/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0427 - accuracy: 0.9891
# Epoch 83/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0398 - accuracy: 0.9895
# Epoch 84/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0425 - accuracy: 0.9895
# Epoch 85/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0433 - accuracy: 0.9891
# Epoch 86/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0449 - accuracy: 0.9885
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0429 - accuracy: 0.9888
# Epoch 88/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0430 - accuracy: 0.9890
# Epoch 89/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0433 - accuracy: 0.9890
# Epoch 90/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0491 - accuracy: 0.9875
# Epoch 91/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0444 - accuracy: 0.9884
# Epoch 92/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0454 - accuracy: 0.9880
# Epoch 93/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0439 - accuracy: 0.9887
# Epoch 94/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0429 - accuracy: 0.9891
# Epoch 95/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0408 - accuracy: 0.9897
# Epoch 96/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0410 - accuracy: 0.9895
# Epoch 97/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0460 - accuracy: 0.9884
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0415 - accuracy: 0.9895
# Epoch 99/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0429 - accuracy: 0.9895
# Epoch 100/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0456 - accuracy: 0.9880

# %%
#최종 train accuracy 측정
metrics=model.evaluate(mnist_train, train_labels, verbose=2)
print("Train accuracy:", metrics[1])
# Out:
# 1875/1875 - 4s - loss: 0.0110 - accuracy: 0.9964
# Train accuracy: 0.9963833093643188

# %%
#학습한 모델로 mnist test data predict
metrics=model.evaluate(mnist_test, test_labels, verbose=2)
print("Test accuracy:", metrics[1])
# Out:
# 313/313 - 1s - loss: 0.0283 - accuracy: 0.9918
# Test accuracy: 0.9918000102043152
