# %% [markdown]
# # Mnist Classification

# %% [markdown]
# ### mnist 데이터 학습을 위해 keras로 cnn 모델을 구성하고 sparse categorical cross entropy를 이용하여 one-hot encoding 없이 학습을 진행해본다.

# %%
##tenssorflow==2.3 환경에서 구현 
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

(mnist_train, mnist_train_label), (mnist_test, mnist_test_label) = mnist.load_data() #mnist data road
#normalization 적용
mnist_train=mnist_train/255
mnist_test=mnist_test/255

mnist_train=tf.cast(mnist_train, tf.float32)
mnist_train=np.expand_dims(mnist_train, -1)
mnist_test=tf.cast(mnist_test, tf.float32)
mnist_test=np.expand_dims(mnist_test, -1)

#one hot encoding을 적용 안함
#train_labels = to_categorical(mnist_train_label, 10)
#test_labels = to_categorical(mnist_test_label, 10) 

class_number = 10

# %%
# keras functional api로 짧은 mlp 모델을 구성 
inputs = tf.keras.Input(shape=(28,28,1))
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=16, activation='relu',padding="same")(inputs)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(1, 1))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(1, 1))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(2, 2))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(2, 2))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu',padding="same")(x)
x = tf.keras.layers.MaxPooling2D((2,2),strides=(2, 2))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Flatten()(x)
outputs = tf.keras.layers.Dense(class_number, activation="softmax")(x)
model = tf.keras.Model(inputs=inputs,outputs=outputs)
model.summary()
model.compile(optimizer='adam', # #one-hot encoding을 안하는 대신에 sparse categorical cross entropy를 loss로 지정
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])
model.fit(mnist_train, mnist_train_label, epochs=100)
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 27, 27, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 27, 27, 16)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 27, 27, 32)        4640
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 26, 26, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 6, 6, 256)         295168
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 3, 3, 256)         0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3, 3, 256)         65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                23050
# =================================================================
# Total params: 481,162
# Trainable params: 481,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9383
# Epoch 2/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9807
# Epoch 3/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9842
# Epoch 4/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9858
# Epoch 5/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9879
# Epoch 6/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9889
# Epoch 7/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9892
# Epoch 8/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0335 - sparse_categorical_accuracy: 0.9898
# Epoch 9/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9894
# Epoch 10/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9903
# Epoch 11/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0322 - sparse_categorical_accuracy: 0.9908
# Epoch 12/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9904
# Epoch 13/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9900
# Epoch 14/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9915
# Epoch 15/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0322 - sparse_categorical_accuracy: 0.9906
# Epoch 16/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0328 - sparse_categorical_accuracy: 0.9903
# Epoch 17/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9903
# Epoch 18/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9908
# Epoch 19/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9904
# Epoch 20/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9905
# Epoch 21/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9902
# Epoch 22/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0297 - sparse_categorical_accuracy: 0.9910
# Epoch 23/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9907
# Epoch 24/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9903
# Epoch 25/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9906
# Epoch 26/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9912
# Epoch 27/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9902
# Epoch 28/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0340 - sparse_categorical_accuracy: 0.9908
# Epoch 29/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9898
# Epoch 30/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9901
# Epoch 31/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0342 - sparse_categorical_accuracy: 0.9901
# Epoch 32/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9898
# Epoch 33/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0340 - sparse_categorical_accuracy: 0.9902
# Epoch 34/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0333 - sparse_categorical_accuracy: 0.9906
# Epoch 35/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9891
# Epoch 36/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9900
# Epoch 37/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0341 - sparse_categorical_accuracy: 0.9907
# Epoch 38/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0377 - sparse_categorical_accuracy: 0.9894
# Epoch 39/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0343 - sparse_categorical_accuracy: 0.9906
# Epoch 40/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0366 - sparse_categorical_accuracy: 0.9897
# Epoch 41/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0346 - sparse_categorical_accuracy: 0.9900
# Epoch 42/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9906
# Epoch 43/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9893
# Epoch 44/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9897
# Epoch 45/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9894
# Epoch 46/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9891
# Epoch 47/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9902
# Epoch 48/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9898
# Epoch 49/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9897
# Epoch 50/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9896
# Epoch 51/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9902
# Epoch 52/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9897
# Epoch 53/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9894
# Epoch 54/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9903
# Epoch 55/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0380 - sparse_categorical_accuracy: 0.9896
# Epoch 56/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9900
# Epoch 57/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9897
# Epoch 58/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9896
# Epoch 59/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0390 - sparse_categorical_accuracy: 0.9898
# Epoch 60/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9902
# Epoch 61/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9892
# Epoch 62/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9888
# Epoch 63/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9888
# Epoch 64/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0357 - sparse_categorical_accuracy: 0.9906
# Epoch 65/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9892
# Epoch 66/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9902
# Epoch 67/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9903
# Epoch 68/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9889
# Epoch 69/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0463 - sparse_categorical_accuracy: 0.9878
# Epoch 70/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9899
# Epoch 71/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9893
# Epoch 72/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9892
# Epoch 73/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9888
# Epoch 74/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9895
# Epoch 75/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9893
# Epoch 76/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9890
# Epoch 77/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9895
# Epoch 78/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9881
# Epoch 79/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9889
# Epoch 80/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9895
# Epoch 81/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9893
# Epoch 82/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9889
# Epoch 83/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9888
# Epoch 84/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0449 - sparse_categorical_accuracy: 0.9887
# Epoch 85/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9890
# Epoch 86/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9890
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0383 - sparse_categorical_accuracy: 0.9900
# Epoch 88/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9895
# Epoch 89/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9901
# Epoch 90/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9895
# Epoch 91/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9894
# Epoch 92/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9897
# Epoch 93/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9882
# Epoch 94/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9902
# Epoch 95/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9882
# Epoch 96/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9880
# Epoch 97/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0430 - sparse_categorical_accuracy: 0.9880
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0464 - sparse_categorical_accuracy: 0.9890
# Epoch 99/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0409 - sparse_categorical_accuracy: 0.9891
# Epoch 100/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9897

# %%
#최종 train accuracy 측정
metrics=model.evaluate(mnist_train, mnist_train_label, verbose=2)
print("Train accuracy:", metrics[1])
# Out:
# 1875/1875 - 4s - loss: 0.0117 - sparse_categorical_accuracy: 0.9965
# Train accuracy: 0.9965000152587891

# %%
#학습한 모델로 mnist test data predict
metrics=model.evaluate(mnist_test, mnist_test_label, verbose=2)
print("Test accuracy:", metrics[1])
# Out:
# 313/313 - 1s - loss: 0.0314 - sparse_categorical_accuracy: 0.9921
# Test accuracy: 0.9921000003814697
